# %%
from aa_lib import *
import pandas as pd

# %%
model_returns = pd.read_pickle('model_returns_final.pkl')
sharpe_df = pd.read_pickle('sharpe_df_final.pkl')

# %%
model_returns.dropna()
# Out:
#              CapPres  Balanced  ProGrowth  AggressiveGrowth  DividendEquity  \
# date
# 2020-04-23 -0.000144  0.000798   0.000856          0.001074       -0.003560
# 2020-04-24  0.005698  0.010767   0.012039          0.012682        0.008448
# 2020-04-27  0.005248  0.015472   0.018236          0.019998        0.022275
# 2020-04-28 -0.001115 -0.001488  -0.001941         -0.001470        0.018895
# 2020-04-29  0.013061  0.024741   0.028436          0.030551        0.033757
# ...              ...       ...        ...               ...             ...
# 2022-07-14 -0.003056 -0.002460  -0.001985         -0.001278       -0.004268
# 2022-07-15  0.007355  0.012999   0.016126          0.019031        0.014852
# 2022-07-18 -0.002308 -0.004530  -0.005754         -0.006797       -0.004276
# 2022-07-19  0.006779  0.017949   0.023611          0.029196        0.020002
# 2022-07-20  0.001711  0.005327   0.007598          0.010153       -0.001053
#
#             OppEquity     Notes   Defined   fairway
# date
# 2020-04-23   0.015128 -0.035594 -0.000012 -0.000611
# 2020-04-24   0.011077  0.024979  0.012682  0.011457
# 2020-04-27   0.024647  0.005846  0.019998  0.004183
# 2020-04-28   0.008511 -0.009311 -0.001470  0.001763
# 2020-04-29   0.054543 -0.007266  0.030551  0.007632
# ...               ...       ...       ...       ...
# 2022-07-14  -0.012834  0.050808 -0.001278  0.000947
# 2022-07-15   0.020649 -0.024499  0.019031  0.006372
# 2022-07-18  -0.000320  0.010815 -0.006797  0.002125
# 2022-07-19   0.027509  0.008658  0.029196 -0.007156
# 2022-07-20   0.014783 -0.020043  0.010153  0.003564
#
# [565 rows x 9 columns]

# %%
ef = get_ef(returns=model_returns, annualize=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 ef = get_ef(returns=model_returns, annualize=True)
#
# File ~\aa_lib.py:101, in get_ef(returns, cov, annualize)
#     100 def get_ef(returns, cov=None, annualize=True):
# --> 101     min_vol = returns.std().min().item()
#     102     max_vol = returns.std().max().item()
#     104     def ef_gen():
#
# AttributeError: 'float' object has no attribute 'item'
